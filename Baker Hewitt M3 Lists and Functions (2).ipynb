# %%
things = ["mozzarella", "cinderella", "salmonella"]
print(things)
# Out:
# ['mozzarella', 'cinderella', 'salmonella']

# %%
things = ["mozzarella", "Cinderella", "salmonella"]
print(things)
# Out:
# ['mozzarella', 'Cinderella', 'salmonella']

# %% [markdown]
# After capitalizing "Cinderella" in the list, it updated with the printed string after running the code

# %%
things = ["MOZZARELLA", "Cinderella", "salmonella"]
print(things)
# Out:
# ['MOZZARELLA', 'Cinderella', 'salmonella']

# %% [markdown]
# After making mozzarella all upper case in the list, it updated with the printed string after running the code

# %%
things = ["MOZZARELLA", "Cinderella"]
print(things)
# Out:
# ['MOZZARELLA', 'Cinderella']

# %% [markdown]
# After deleting salmonela, I collected my nobel prize and noticed it was gone from the list

# %%
def good():
    return ['Harry', 'Ron', 'Hermione']
print(good())
# Out:
# ['Harry', 'Ron', 'Hermione']

# %%
def get_odds():
    for num in range(10):
        if num % 2 == 1:
            yield num
count = 0

for odd in get_odds():
    count += 1
    if count == 3:
        print(odd)
        break
# Out:
# 5
